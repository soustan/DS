# %% [markdown]
# <a href="https://colab.research.google.com/github/soustan/DS/blob/main/DS_06_02_2023vs01_01_2021vs23_01_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! gdown  https://drive.google.com/uc?id=1fDHweUp3533QssABMD3pSfQ9VyaLJE3d
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1fDHweUp3533QssABMD3pSfQ9VyaLJE3d
# To: /content/DS-06-02-2023vs01-01-2021vs23-01-2023.xlsx
# 100% 2.41M/2.41M [00:00<00:00, 173MB/s]

# %%
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
import scipy
import seaborn as sns
import sklearn.linear_model as lm
import statsmodels.api as sm
import statsmodels.api as smf
import statsmodels.api as stats

# %%
DS = pd.read_excel('DS-06-02-2023vs01-01-2021vs23-01-2023.xlsx')

# %%
DS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 44 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Дата                              10781 non-null  object
#  1   Наименование                      10781 non-null  object
#  2   Основной вид деятельности         10781 non-null  object
#  3   ИНН                               10781 non-null  int64
#  4   КЭ                                89 non-null     object
#  5   ФОКУС                             2 non-null      object
#  6   ДД                                20 non-null     object
#  7   ЭДО-ЭТП                           0 non-null      float64
#  8   ОФД                               0 non-null      float64
#  9   ОТЧЕТ-РУ                          0 non-null      float64
#  10  НРМТВ                             0 non-null      float64
# ...

# %%
DS.head()
# Out:
#                      Дата                  Наименование  \
# 0  01-01-2021vs28-03-2022              ООО "Улыбинское"
# 1  01-01-2021vs28-03-2022                     ООО "Ача"
# 2  01-01-2021vs28-03-2022          ООО "Совхоз Борский"
# 3  01-01-2021vs28-03-2022             ООО "Шагаловское"
# 4  01-01-2021vs28-03-2022  ООО "Сибирские Черные Земли"
#
#                            Основной вид деятельности         ИНН   КЭ ФОКУС  \
# 0  01.11 Выращивание зерновых (кроме риса), зерно...  5425025071    +   NaN
# 1  01.11 Выращивание зерновых (кроме риса), зерно...  5413001189  NaN   NaN
# 2  01.11 Выращивание зерновых (кроме риса), зерно...  5413001171  NaN   NaN
# 3  01.11 Выращивание зерновых (кроме риса), зерно...  5405061106    +   NaN
# 4  01.11 Выращивание зерновых (кроме риса), зерно...  5410093181  NaN   NaN
#
#     ДД  ЭДО-ЭТП  ОФД  ОТЧЕТ-РУ  ...  Чистая прибыль/ убыток, тыс. руб  \
# 0  NaN      NaN  NaN       NaN  ...                             -38.0
# ...
